# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("/content/a1_Dataset_10Percent.xlsx")

# %%
data.head()
# Out:
#          ID  DemAffl  DemAge DemClusterGroup DemGender    DemReg DemTVReg  \
# 0  17147654      5.0     NaN             NaN       NaN       NaN      NaN
# 1   8415498     15.0     NaN             NaN         M       NaN      NaN
# 2  12107603      NaN     NaN             NaN         M  Midlands     East
# 3  14400995      8.0    28.0             NaN         F       NaN      NaN
# 4  28724674     14.0    67.0             NaN       NaN       NaN      NaN
#
#   LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# 0        Tin        0.01        5.0          0
# 1       Gold     8000.00        5.0          1
# 2        Tin        0.01        NaN          1
# 3        Tin        0.01        NaN          1
# 4        Tin        0.01        7.0          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22223 entries, 0 to 22222
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               22223 non-null  int64
#  1   DemAffl          21138 non-null  float64
#  2   DemAge           20715 non-null  float64
#  3   DemClusterGroup  21549 non-null  object
#  4   DemGender        19711 non-null  object
#  5   DemReg           21758 non-null  object
#  6   DemTVReg         21758 non-null  object
#  7   LoyalClass       22223 non-null  object
#  8   LoyalSpend       22223 non-null  float64
#  9   LoyalTime        21942 non-null  float64
#  10  TargetBuy        22223 non-null  int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.9+ MB

# %%
#analyzing null value in the data set
data.isna().sum()
# Out:
# ID                    0
# DemAffl            1085
# DemAge             1508
# DemClusterGroup     674
# DemGender          2512
# DemReg              465
# DemTVReg            465
# LoyalClass            0
# LoyalSpend            0
# LoyalTime           281
# TargetBuy             0
# dtype: int64

# %%
#filling the missing values with either mean or the mode
data['DemAffl']=data['DemAffl'].fillna(data['DemAffl'].mode()[0])
data['DemAge']=data['DemAge'].fillna(data['DemAge'].mode()[0])
data['DemClusterGroup']=data['DemClusterGroup'].fillna(data['DemClusterGroup'].mode()[0])
data['DemGender']=data['DemGender'].fillna(data['DemGender'].mode()[0])
data['DemReg']=data['DemReg'].fillna(data['DemReg'].mode()[0])
data['DemTVReg']=data['DemTVReg'].fillna(data['DemTVReg'].mode()[0])
data['LoyalTime']=data['LoyalTime'].fillna(data['LoyalTime'].mean()) # for categorical data we will use mean and for continious data we will use mode

# %%
data.head()
# Out:
#          ID  DemAffl  DemAge DemClusterGroup DemGender      DemReg DemTVReg  \
# 0  17147654      5.0    51.0               C         F  South East   London
# 1   8415498     15.0    51.0               C         M  South East   London
# 2  12107603      8.0    51.0               C         M    Midlands     East
# 3  14400995      8.0    28.0               C         F  South East   London
# 4  28724674     14.0    67.0               C         F  South East   London
#
#   LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# 0        Tin        0.01    5.00000          0
# 1       Gold     8000.00    5.00000          1
# 2        Tin        0.01    6.56467          1
# 3        Tin        0.01    6.56467          1
# 4        Tin        0.01    7.00000          0

# %%
data.isna().sum()
# Out:
# ID                 0
# DemAffl            0
# DemAge             0
# DemClusterGroup    0
# DemGender          0
# DemReg             0
# DemTVReg           0
# LoyalClass         0
# LoyalSpend         0
# LoyalTime          0
# TargetBuy          0
# dtype: int64

# %%
data.head()
# Out:
#          ID  DemAffl  DemAge DemClusterGroup DemGender      DemReg DemTVReg  \
# 0  17147654      5.0    51.0               C         F  South East   London
# 1   8415498     15.0    51.0               C         M  South East   London
# 2  12107603      8.0    51.0               C         M    Midlands     East
# 3  14400995      8.0    28.0               C         F  South East   London
# 4  28724674     14.0    67.0               C         F  South East   London
#
#   LoyalClass  LoyalSpend  LoyalTime  TargetBuy
# 0        Tin        0.01    5.00000          0
# 1       Gold     8000.00    5.00000          1
# 2        Tin        0.01    6.56467          1
# 3        Tin        0.01    6.56467          1
# 4        Tin        0.01    7.00000          0

# %%
data.isna().sum()
# Out:
# ID                 0
# DemAffl            0
# DemAge             0
# DemClusterGroup    0
# DemGender          0
# DemReg             0
# DemTVReg           0
# LoyalClass         0
# LoyalSpend         0
# LoyalTime          0
# TargetBuy          0
# dtype: int64

# %%
#using label encoding to convert Categorical Values into numeric data
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()

# %%
data['DemClusterGroup']=label_encoder.fit_transform(data['DemClusterGroup'])

# %%
data['DemClusterGroup'].unique()
# Out:
# array([2, 1, 4, 3, 5, 0, 6])

# %%
data['DemGender'].unique()
# Out:
# array(['F', 'M', 'U'], dtype=object)

# %%
data['Demgender']=label_encoder.fit_transform(data['DemGender'])

# %%
data['DemReg'].unique()
# Out:
# array(['South East', 'Midlands', 'North', 'South West', 'Scottish'],
#       dtype=object)

# %%
data['DemReg']=label_encoder.fit_transform(data['DemReg'])

# %%
data['DemReg'].unique()
# Out:
# array([3, 0, 1, 4, 2])

# %%
data['DemTVReg'].unique()
# Out:
# array(['London', 'East', 'Ulster', 'S & S East', 'Yorkshire',
#        'Wales & West', 'N West', 'Midlands', 'S West', 'N East', 'N Scot',
#        'C Scotland', 'Border'], dtype=object)

# %%
data['DemTVReg']=label_encoder.fit_transform(data['DemTVReg'])

# %%
data['DemTVReg'].unique()
# Out:
# array([ 3,  2, 10,  8, 12, 11,  7,  4,  9,  5,  6,  1,  0])

# %%
data['LoyalClass'].unique()
# Out:
# array(['Tin', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
data['LoyalClass']=label_encoder.fit_transform(data['LoyalClass'])

# %%
data['LoyalClass'].unique()
# Out:
# array([3, 0, 2, 1])

# %%
#count pf customer in each loyal_class
data['LoyalClass'].value_counts()
# Out:
# LoyalClass
# 2    8572
# 3    6487
# 0    6324
# 1     840
# Name: count, dtype: int64

# %%
data.head()
# Out:
#          ID  DemAffl  DemAge  DemClusterGroup DemGender  DemReg  DemTVReg  \
# 0  17147654      5.0    51.0                2         F       3         3
# 1   8415498     15.0    51.0                2         M       3         3
# 2  12107603      8.0    51.0                2         M       0         2
# 3  14400995      8.0    28.0                2         F       3         3
# 4  28724674     14.0    67.0                2         F       3         3
#
#    LoyalClass  LoyalSpend  LoyalTime  TargetBuy  Demgender
# 0           3        0.01    5.00000          0          0
# 1           0     8000.00    5.00000          1          1
# 2           3        0.01    6.56467          1          1
# 3           3        0.01    6.56467          1          0
# 4           3        0.01    7.00000          0          0

# %%
df=data.drop(['ID'],axis=1)

# %%
data.head()
# Out:
#          ID  DemAffl  DemAge  DemClusterGroup DemGender  DemReg  DemTVReg  \
# 0  17147654      5.0    51.0                2         F       3         3
# 1   8415498     15.0    51.0                2         M       3         3
# 2  12107603      8.0    51.0                2         M       0         2
# 3  14400995      8.0    28.0                2         F       3         3
# 4  28724674     14.0    67.0                2         F       3         3
#
#    LoyalClass  LoyalSpend  LoyalTime  TargetBuy  Demgender
# 0           3        0.01    5.00000          0          0
# 1           0     8000.00    5.00000          1          1
# 2           3        0.01    6.56467          1          1
# 3           3        0.01    6.56467          1          0
# 4           3        0.01    7.00000          0          0

# %%
# Data Visualization - EDA
# Histogram: show the distribution of numerical features, allowing us to
#understand their spread and identify potential skewness or outliers.
print("Histograms for numerical features:")
data.hist(bins=25, figsize=(15, 10))
plt.suptitle('Distribution of Numerical Features')
plt.show()
# Out:
# Histograms for numerical features:

# %% [markdown]
# ID: IDs are relatively uniformly distributed, with some peaks indicating specific concentrations.
#
# DemAffl: Right-skewed distribution, with most values concentrated between 0 and 10, indicating varying levels of affluence.
#
# DemAge: Normal distribution centered around 50, indicating the majority of individuals are around this age.
#
# DemClusterGroup: Uniform distribution with some peaks, suggesting certain cluster groups are more represented.
#
# DemGender: Bimodal distribution with peaks at 0 and 1, representing two primary gender categories.
#
# DemReg: Peaks at 0, 2, and 3, indicating some regions are more represented.
#
# DemTVReg: Various peaks, suggesting certain TV regions have higher representation.
#
# LoyalClass: Peaks at 0, 1, and 2, indicating different loyalty classes.
#
# LoyalSpend: Right-skewed distribution, with most values near 0, showing low spending for most individuals.
#
# LoyalTime: Right-skewed distribution, with most values between 0 and 10, indicating low loyalty time for most individuals.
#
# TargetBuy: Bimodal distribution with peaks at 0 and 1, representing two primary buying behaviors.

# %% [markdown]
# >>>>>>

# %%
# Box plots for numerical features to identify outliers in the LoyalTime.
print("Box plot for LoyalTime:")
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['LoyalTime'])
plt.title('Box plot for LoyalTime')
plt.show()
# Out:
# Box plot for LoyalTime:

# %% [markdown]
# From the above box plot of LoyalTime helps in identifying outliers in this feature: Any points outside the whiskers of the box plot are considered outliers.
#
# Outliers: Highlights anomalies or unique behaviors.
#
# Median: Shows the central loyalty time value.
#
# Spread: Displays the variability within the middle 50% of the data.
#
# Whiskers: Indicates the range covering most data points.

# %% [markdown]
# >>>>>

# %%
# Correlation matrix shows the relationships between features. Strong correlations
# can indicate redundancy, while weak correlations might suggest independent features.
print("Correlation Matrix:")
numeric_df = df.select_dtypes(include=[np.number])
corr_matrix = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Correlation Matrix:

# %% [markdown]
# from the above Corelation Matrix:
#
# DemAffl and TargetBuy: Moderate positive correlation (0.35) suggests that higher affluence is associated with increased likelihood of purchase.
#
# DemAge and LoyalClass: Moderate negative correlation (-0.34) indicates that older individuals are less likely to belong to higher loyalty classes.
#
# LoyalClass and LoyalSpend: Strong negative correlation (-0.54) shows that higher loyalty classes are associated with lower spending.
#
# DemAge and LoyalSpend: Moderate positive correlation (0.26) suggests that older individuals tend to spend more.
#
# TargetBuy and DemAge: Moderate negative correlation (-0.29) indicates that older individuals are less likely to make a purchase.
#
# DemAffl and DemAge: Weak negative correlation (-0.13) suggests a slight trend where older individuals may have lower affluence.

# %% [markdown]
# >>>>>>

# %%
"""Count plot for categorical features distribution of gender in the dataset,
indicating if there is any imbalance between male and female customers."""

print("Count plot for DemGender:")
plt.figure(figsize=(10, 5))
sns.countplot(x='DemGender', data=data)
plt.title('Count plot for DemGender')
plt.show()
# Out:
# Count plot for DemGender:

# %% [markdown]
# From the Above Count Plot:
#
# Female (F): Highest count at approximately 14,500.
#
# Male (M): Moderate count at approximately 6,500.
#
# Unknown (U): Lowest count at approximately 2,000.
#
# This summary highlights the distribution of the demographic variable DemGender, showing a higher representation of females compared to males and unknowns

# %% [markdown]
# >>>>>>

# %%
#The count plot shows the distribution of loyal classes in the dataset, helping to understand the proportion of each class.
print("Count plot for LoyalClass:")
plt.figure(figsize=(10, 5))
sns.countplot(x='LoyalClass', data=data)
plt.title('Count plot for LoyalClass')
plt.show()
# Out:
# Count plot for LoyalClass:

# %% [markdown]
# From the Above Count Plot:
#
# Class 2: Highest count, around 9000.
#
# Class 0: Second highest count, around 6500.
#
# Class 3: Moderate count, around 6000.
#
# Class 1: Lowest count, around 1000.
#
# This summary highlights the distribution of loyalty classes, with Class 2 being the most frequent and Class 1 the least.

# %%
#The scatter plot helps to visualize the relationship between LoyalTime and DemAge, with different colors representing different loyal classes.
print("Scatter plot between LoyalTime and DemAge:")
plt.figure(figsize=(10, 5))
sns.scatterplot(x='LoyalTime', y='DemAge', hue='LoyalClass', data=data)
plt.title('Scatter plot between LoyalTime and DemAge')
plt.show()
# Out:
# Scatter plot between LoyalTime and DemAge:

# %% [markdown]
# From the above Scatter Plot:
#
# Concentration: Most data points are concentrated in the lower range of LoyalTime (0-10).
#
# Age Distribution: The age range is between 20 and 80, with no clear pattern of age affecting loyalty time.
#
# LoyalClass Distribution: Different LoyalClass categories are evenly spread, with no dominant class in any specific area.
#
# This scatter plot provides an overview of the relationship between loyalty time and age, with no strong trends or patterns for specific loyalty classes.

# %%
# Separate independent and dependent variables
x=df.drop(['TargetBuy'],axis=1) #Independent variables
y=df['TargetBuy'] #dependent variable

# %%
x=df.drop(['DemGender'],axis=1)
y=df['DemGender']

# %%
x.head()
# Out:
#    DemAffl  DemAge  DemClusterGroup  DemReg  DemTVReg  LoyalClass  LoyalSpend  \
# 0      5.0    51.0                2       3         3           3        0.01
# 1     15.0    51.0                2       3         3           0     8000.00
# 2      8.0    51.0                2       0         2           3        0.01
# 3      8.0    28.0                2       3         3           3        0.01
# 4     14.0    67.0                2       3         3           3        0.01
#
#    LoyalTime  TargetBuy  Demgender
# 0    5.00000          0          0
# 1    5.00000          1          1
# 2    6.56467          1          1
# 3    6.56467          1          0
# 4    7.00000          0          0

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
# Train a Logistic Regression model
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()

# %%
classifier.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Predict on the test set
predictions=classifier.predict(x_test)

# %%
# Evaluate the model
from sklearn.metrics import confusion_matrix, accuracy_score
cm=confusion_matrix(predictions,y_test)

# %%
ac=accuracy_score(predictions,y_test)

# %%
# Print the confusion matrix and accuracy score
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[1463  534  146]
#  [  10   27   43]
#  [   0    0    0]]

# %%
print("Accuracy Score:")
print(ac)
# Out:
# Accuracy Score:
# 0.6702654071075124

# %% [markdown]
# >>>>>>>>

# %% [markdown]
# >>>>>>>>>
